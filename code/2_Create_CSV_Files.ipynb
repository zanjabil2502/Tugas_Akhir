# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
from collections import OrderedDict

# %%
if os.path.exists('csv_files')==False:
    os.mkdir('csv_files')

# %% [markdown]
# ## Create Coswara's CSV File

# %%
names   = ['ID','STATUS','DIR','DataSet']
join_by = pd.read_csv('dataset/Coswara-Data/combined_data.csv')

import glob
df_list = []
for path in tqdm(glob.glob('dataset/Coswara-Data/*/*/cough-shallow.wav')):
    temp = pd.DataFrame(columns=['id','DIR'])
    temp['id'] = [path.split('/')[-2]]
    temp['DIR'] = [path]
    temp = pd.merge(left=temp,right=join_by,on='id',how='inner')
    temp = temp[['id','covid_status','DIR']]
    df_list.append(temp.rename(columns={'id':'ID','covid_status':'STATUS','DIR':'DIR'}))
CosData=pd.concat(df_list)
CosData['DataSet'] = 'coswara'
CosData   = CosData.sample(frac=1).reset_index(drop=True)
CosData.to_csv('csv_files/Coswara_dataset.csv', index=False)
CosData.head()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2232/2232 [00:11<00:00, 187.79it/s]
#                              ID             STATUS  \
# 0  d7w3B2YcJ3TLx58ryhiASEtwaAu1  positive_moderate
# 1  bg0A9VSw8yUI2XHBYnyjRTF6Yk83     recovered_full
# 2  1pXSBzMeizcu5IpLAJUaYpmJyhB3            healthy
# 3  1kj3twlB9PcVyePxzqNGwnkYZZx2            healthy
# 4  1CtdDsZvTshuIGrVGvF9pilcHP13            healthy
#
#                                                  DIR  DataSet
# 0  dataset/Coswara-Data/20210930/d7w3B2YcJ3TLx58r...  coswara
# 1  dataset/Coswara-Data/20210830/bg0A9VSw8yUI2XHB...  coswara
# 2  dataset/Coswara-Data/20200415/1pXSBzMeizcu5IpL...  coswara
# 3  dataset/Coswara-Data/20200415/1kj3twlB9PcVyePx...  coswara
# 4  dataset/Coswara-Data/20200417/1CtdDsZvTshuIGrV...  coswara

# %%
status = []
for index,row in CosData.iterrows():
    cat = row['STATUS']
    status.append(cat)
category = list(OrderedDict.fromkeys(status))
print(category)
# Out:
# ['positive_moderate', 'recovered_full', 'healthy', 'no_resp_illness_exposed', 'positive_mild', 'resp_illness_not_identified', 'positive_asymp']

# %%
names   = ['ID','STATUS','DIR','DataSet']
join_by = pd.read_csv('dataset/Coswara-Data/combined_data.csv')

import glob
df_list = []
for path in tqdm(glob.glob('dataset/Coswara-Data/*/*/cough-heavy.wav')):
    temp = pd.DataFrame(columns=['id','DIR'])
    temp['id'] = [path.split('/')[-2]]
    temp['DIR'] = [path]
    temp = pd.merge(left=temp,right=join_by,on='id',how='inner')
    temp = temp[['id','covid_status','DIR']]
    df_list.append(temp.rename(columns={'id':'ID','covid_status':'STATUS','DIR':'DIR'}))
HevData=pd.concat(df_list)
HevData['DataSet'] = 'coswara'
HevData   = HevData.sample(frac=1).reset_index(drop=True)
HevData.to_csv('csv_files/Coswara_heavy_dataset.csv', index=False)
HevData.head()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2233/2233 [00:11<00:00, 186.61it/s]
#                              ID                       STATUS  \
# 0  ddjJ6wgPMRXzqByVDrLeTEVPzF32      no_resp_illness_exposed
# 1  AWMx6dOBlFPdjWa86wkLjsGZ6by2                positive_mild
# 2  wByjVbPfagQsv9nerwycE1QDQ5B3                      healthy
# 3  ijTkM1TDeeXxjotuSx0D7Bhk2H72  resp_illness_not_identified
# 4  8Suz7Jl7GtXpdB7UeIPtLuZb1Lp2                      healthy
#
#                                                  DIR  DataSet
# 0  dataset/Coswara-Data/20200814/ddjJ6wgPMRXzqByV...  coswara
# 1  dataset/Coswara-Data/20210630/AWMx6dOBlFPdjWa8...  coswara
# 2  dataset/Coswara-Data/20200416/wByjVbPfagQsv9ne...  coswara
# 3  dataset/Coswara-Data/20210830/ijTkM1TDeeXxjotu...  coswara
# 4  dataset/Coswara-Data/20200525/8Suz7Jl7GtXpdB7U...  coswara

# %% [markdown]
# ## Create Coughvid's CSV File

# %%
coughvid  = 'dataset/Coughvid-Data/public_dataset/'

VidData   = pd.read_csv(os.path.join(coughvid,'metadata_compiled.csv'),header=0)
VidData   = VidData.loc[VidData['cough_detected'] >= 0.0][['uuid','status']]
VidData.dropna(inplace=True)

extradata = VidData.loc[VidData['status']=='COVID-19']
notradata = VidData.loc[VidData['status']!='COVID-19']

VidData   = pd.concat([extradata,notradata],ignore_index= True)
VidData['DIR'] = coughvid + VidData['uuid'] + '.webm'
VidData['DataSet'] = 'coughvid'
VidData.rename(columns={'uuid': 'ID', 'status': 'STATUS'}, inplace=True)
VidData   = VidData.sample(frac=1).reset_index(drop=True)
VidData.to_csv('csv_files/Coughvid_dataset.csv', index=False)
VidData.head()
# Out:
#                                      ID       STATUS  \
# 0  5e232ea7-d639-4ec9-99b2-1829528cdf1c      healthy
# 1  d82e3da4-5f62-4ab7-b638-f13227265c87      healthy
# 2  3ee7c038-24df-471b-a265-5284667c8de5      healthy
# 3  e23df0a2-fc36-4f70-a883-cf49d80aeb5b      healthy
# 4  c805cfe3-e1a5-45d4-bf59-cfef6d2d8d43  symptomatic
#
#                                                  DIR   DataSet
# 0  dataset/Coughvid-Data/public_dataset/5e232ea7-...  coughvid
# 1  dataset/Coughvid-Data/public_dataset/d82e3da4-...  coughvid
# 2  dataset/Coughvid-Data/public_dataset/3ee7c038-...  coughvid
# 3  dataset/Coughvid-Data/public_dataset/e23df0a2-...  coughvid
# 4  dataset/Coughvid-Data/public_dataset/c805cfe3-...  coughvid

# %%
status = []
for index,row in VidData.iterrows():
    cat = row['STATUS']
    status.append(cat)
category = list(OrderedDict.fromkeys(status))
print(category)
# Out:
# ['healthy', 'symptomatic', 'COVID-19']

# %% [markdown]
# ## Create Compare's CSV File

# %%
compare = 'dataset/Compare-Data/dist/wav'
df = pd.read_csv('dataset/Compare-Data/metaData_CCS.csv')
df_list = []
for index,row in tqdm(df.iterrows()):
    temp = pd.DataFrame(columns=['ID','STATUS','DIR','DataSet'])
    temp['ID'] = [row['Uid']]
    temp['STATUS'] = [row['label']]
    fn = row['filename']
    temp['DIR'] = [os.path.join(compare,fn)]
    temp['DataSet'] = ['compare']
    df_list.append(temp)
CompData = pd.concat(df_list)
CompData = CompData.sample(frac=1).reset_index(drop=True)
CompData.to_csv('csv_files/Compare_dataset.csv', index=False)
CompData.head()
# Out:
# 725it [00:01, 601.13it/s]
#              ID    STATUS                                          DIR  \
# 0  JGpHEEyLLkP6  negative   dataset/Compare-Data/dist/wav/test_083.wav
# 1  S2M9zRm5K5tE  negative  dataset/Compare-Data/dist/wav/train_065.wav
# 2    St2tfgDrX8  positive  dataset/Compare-Data/dist/wav/devel_211.wav
# 3    ChZ56JFWqW  negative  dataset/Compare-Data/dist/wav/devel_231.wav
# 4    WY8IG2M8yV  negative  dataset/Compare-Data/dist/wav/train_021.wav
#
#    DataSet
# 0  compare
# 1  compare
# 2  compare
# 3  compare
# 4  compare

# %% [markdown]
# ## Merge CSV

# %%
CosData = pd.read_csv('csv_files/Coswara_dataset.csv')
HevData = pd.read_csv('csv_files/Coswara_heavy_dataset.csv')
VidData = pd.read_csv('csv_files/Coughvid_dataset.csv')
CompData = pd.read_csv('csv_files/Compare_dataset.csv')
PosData = pd.read_csv('csv_files/Coswara_positive_heavy_dataset.csv')
Pos_Data = pd.read_csv('csv_files/Coswara_positive_shallow_dataset.csv')
Posvid_Data = pd.read_csv('csv_files/Coughvid_positive_dataset.csv')

# %%
MergeData = pd.concat([Pos_Data, PosData, Posvid_Data, CompData])
MergeData   = MergeData.sample(frac=1).reset_index(drop=True)
df_list = []
for index,row in tqdm(MergeData.iterrows()):
    temp = pd.DataFrame(columns=['ID','STATUS','DIR','DataSet'])
    diagnose = row['STATUS']
    if diagnose == 'healthy' or diagnose == 'negative':
        status = 'negative'
        temp['ID'] = [row['ID']]
        temp['STATUS'] = [status]
        temp['DIR'] = [row['DIR']]
        temp['DataSet'] = [row['DataSet']] 
    elif diagnose == 'positive_moderate' or diagnose == 'positive_mild' or diagnose == 'positive_asymp' or diagnose == 'positive' or diagnose == 'COVID-19':
        status = 'positive'
        temp['ID'] = [row['ID']]
        temp['STATUS'] = [status]
        temp['DIR'] = [row['DIR']]
        temp['DataSet'] = [row['DataSet']]
    df_list.append(temp)
MergeData = pd.concat(df_list)
MergeData = MergeData.sample(frac=1).reset_index(drop=True)
MergeData.to_csv('csv_files/Merge_dataset.csv', index=False)
MergeData.head()
# Out:
# 2595it [00:03, 661.24it/s]
#                                      ID    STATUS  \
# 0                            dncKMesQw1  negative
# 1          DGWrVMD5yZc5jcjMzblC4kaBLmK2  positive
# 2          d6tJkKV7x1TFBe8WNnLhvLuoXgd2  positive
# 3          H7CA9UCGWhXOL2ycjqtRBHNXMsk1  positive
# 4  774bafb8-5d1c-42c5-a0a8-91ba0a85a04b  positive
#
#                                                  DIR   DataSet
# 0        dataset/Compare-Data/dist/wav/devel_015.wav   compare
# 1  dataset/Coswara-Data/20200919/DGWrVMD5yZc5jcjM...   coswara
# 2  dataset/Coswara-Data/20210426/d6tJkKV7x1TFBe8W...   coswara
# 3  dataset/Coswara-Data/20210930/H7CA9UCGWhXOL2yc...   coswara
# 4  dataset/Coughvid-Data/public_dataset/774bafb8-...  coughvid

# %%
df = pd.read_csv('csv_files/Merge_dataset.csv')
df_list = []
for index,row in tqdm(df.iterrows()):
    temp = pd.DataFrame(columns=['ID','STATUS','DIR','DataSet'])
    diagnose = row['STATUS']
    dataset = row['DataSet']
    paths = row['DIR']
    if dataset == 'coswara':
        if diagnose == 'positive':
            pt = paths.split('/')[-1]
            if pt == 'cough-heavy.wav':
                temp['ID'] = [row['ID']]
                temp['STATUS'] = [diagnose]
                temp['DIR'] = [paths]
                temp['DataSet'] = [row['DataSet']] 

    df_list.append(temp)
PosData = pd.concat(df_list)
PosData = PosData.sample(frac=1).reset_index(drop=True)
PosData.to_csv('csv_files/Coswara_positive_heavy_dataset.csv', index=False)
PosData.head()
# Out:
# 13914it [00:12, 1080.81it/s]
#                              ID    STATUS  \
# 0  XFlqN1sDBKNXyuORhVagkJnr5V33  positive
# 1  vXpopcJJEugOInwUtJkEnHgoVhk1  positive
# 2  UhYCvhOCn2erbzJc5faN4ek3D1I2  positive
# 3  TQCxi7zzXCTlowvfaJyctxGYNUx1  positive
# 4  u4k3fup3JdfVBjA86vjrMVth3063  positive
#
#                                                  DIR  DataSet
# 0  dataset/Coswara-Data/20200911/XFlqN1sDBKNXyuOR...  coswara
# 1  dataset/Coswara-Data/20210930/vXpopcJJEugOInwU...  coswara
# 2  dataset/Coswara-Data/20200901/UhYCvhOCn2erbzJc...  coswara
# 3  dataset/Coswara-Data/20210523/TQCxi7zzXCTlowvf...  coswara
# 4  dataset/Coswara-Data/20210523/u4k3fup3JdfVBjA8...  coswara

# %%
df = pd.read_csv('csv_files/Merge_dataset.csv')
df_list = []
for index,row in tqdm(df.iterrows()):
    temp = pd.DataFrame(columns=['ID','STATUS','DIR','DataSet'])
    diagnose = row['STATUS']
    dataset = row['DataSet']
    paths = row['DIR']
    if dataset == 'coswara':
        if diagnose == 'positive':
            pt = paths.split('/')[-1]
            if pt == 'cough-shallow.wav':
                temp['ID'] = [row['ID']]
                temp['STATUS'] = [diagnose]
                temp['DIR'] = [paths]
                temp['DataSet'] = [row['DataSet']] 

    df_list.append(temp)
Pos_Data = pd.concat(df_list)
Pos_Data = Pos_Data.sample(frac=1).reset_index(drop=True)
Pos_Data.to_csv('csv_files/Coswara_positive_shallow_dataset.csv', index=False)
Pos_Data.head()
# Out:
# 13914it [00:12, 1091.02it/s]
#                              ID    STATUS  \
# 0  Fh3hBZZRh2UXXicTNGMei8ikbSu2  positive
# 1  Y635Ri3QFMcOKC0ckXgW2r0xJ422  positive
# 2  o8LJfYAChnd5Jv0WVa6Ni7jpHf92  positive
# 3  hNAGUEhL2Nh7V89at3yFEjQYo6c2  positive
# 4  iaLzL5BAVHXg0Ng0Phw6WMZHEkg2  positive
#
#                                                  DIR  DataSet
# 0  dataset/Coswara-Data/20210406/Fh3hBZZRh2UXXicT...  coswara
# 1  dataset/Coswara-Data/20200820/Y635Ri3QFMcOKC0c...  coswara
# 2  dataset/Coswara-Data/20210816/o8LJfYAChnd5Jv0W...  coswara
# 3  dataset/Coswara-Data/20200417/hNAGUEhL2Nh7V89a...  coswara
# 4  dataset/Coswara-Data/20210426/iaLzL5BAVHXg0Ng0...  coswara

# %%
df = pd.read_csv('csv_files/Merge_dataset.csv')
df_list = []
for index,row in tqdm(df.iterrows()):
    temp = pd.DataFrame(columns=['ID','STATUS','DIR','DataSet'])
    diagnose = row['STATUS']
    dataset = row['DataSet']
    dirs  = row['DIR']
    if dataset == 'coughvid':
        if diagnose == 'positive':
            temp['ID'] = [row['ID']]
            temp['STATUS'] = [diagnose]
            temp['DIR'] = [dirs]
            temp['DataSet'] = [row['DataSet']] 
    df_list.append(temp)
Posvid_Data = pd.concat(df_list)
Posvid_Data = Posvid_Data.sample(frac=1).reset_index(drop=True)
Posvid_Data.to_csv('csv_files/Coughvid_positive_dataset.csv', index=False)
Posvid_Data.head()
# Out:
# 13914it [00:13, 1055.33it/s]
#                                      ID    STATUS  \
# 0  3db14b07-2720-4fa9-870a-725fda24a0bd  positive
# 1  ed432a19-0e50-4864-8cfd-8db00d940249  positive
# 2  6604cf63-454a-4b13-9fc9-95eb74566e8e  positive
# 3  ed988dfa-0bc8-409d-adea-4b44350ad946  positive
# 4  fd849b72-f4bf-4852-9bc2-fd9becc9571e  positive
#
#                                                  DIR   DataSet
# 0  dataset/Coughvid-Data/public_dataset/3db14b07-...  coughvid
# 1  dataset/Coughvid-Data/public_dataset/ed432a19-...  coughvid
# 2  dataset/Coughvid-Data/public_dataset/6604cf63-...  coughvid
# 3  dataset/Coughvid-Data/public_dataset/ed988dfa-...  coughvid
# 4  dataset/Coughvid-Data/public_dataset/fd849b72-...  coughvid

# %%
df = pd.read_csv('csv_files/Merge_dataset.csv')
df_list = []
for index,row in df.iterrows():
    dataset = row['DataSet']
    cat = row['STATUS']
    dirs = row['DIR']
    paths = dirs.split('/')[-1]
    if dataset == 'coswara':
        if cat == 'positive' :
            if paths == 'cough-heavy.wav':
                df_list.append(dataset)

# %%
len(df_list)
# Out:
# 430

# %%
len(df_list)
# Out:
# 430
