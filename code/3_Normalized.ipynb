# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import librosa as lb
from scipy.io.wavfile import write 
import matplotlib.pyplot as plt
import shutil

# %%
if os.path.exists('csv_files/normalized_data/')==False:
    os.mkdir('csv_files/normalized_data/')

# %%
if os.path.exists('dataset/Coughvid-Data/wav')==False:
    os.mkdir('dataset/Coughvid-Data/wav')

# %% [markdown]
# ## Converting webm files to wav files

# %%
coughvid = pd.read_csv('csv_files/Merge_dataset.csv')
for index,row in tqdm(coughvid.iterrows()):
    dataset = row['DataSet']
    if dataset == 'coughvid':
        paths = row['DIR']
        fn = paths.split('/')[-1].split('.')[0]
        loc = os.path.join('dataset/Coughvid-Data/wav',fn+'.wav')
        if os.path.exists(paths) == True:
            if (paths.endswith(".webm")):
                command = f"ffmpeg -i  {paths} -c:a pcm_f32le {loc}"
                os.system(command)
# Out:
# 0it [00:00, ?it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/0bbd9a2b-864f-49fa-9bdf-2cb78d7ca149.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/0bbd9a2b-864f-49fa-9bdf-2cb78d7ca149.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1856kB time=00:00:09.84 bitrate=1545.4kbits/s speed= 687x
# video:0kB audio:1856kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005997%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/660f52df-42dc-49e9-ac87-473c6db99d17.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/660f52df-42dc-49e9-ac87-473c6db99d17.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1856kB time=00:00:09.83 bitrate=1545.5kbits/s speed= 702x
# video:0kB audio:1856kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005997%
# 14it [00:00, 129.54it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/ee42cab8-6560-49b4-bb5e-bdeaa8f99751.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/ee42cab8-6560-49b4-bb5e-bdeaa8f99751.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1845kB time=00:00:09.77 bitrate=1545.6kbits/s speed= 690x
# video:0kB audio:1845kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006034%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/db234c88-9a58-4947-a852-d7f2584128ef.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/db234c88-9a58-4947-a852-d7f2584128ef.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1868kB time=00:00:09.91 bitrate=1543.8kbits/s speed= 590x
# video:0kB audio:1868kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005961%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/5d1fff93-65cd-49dd-b9d4-3303e350b546.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/5d1fff93-65cd-49dd-b9d4-3303e350b546.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1778kB time=00:00:09.41 bitrate=1546.0kbits/s speed= 692x
# video:0kB audio:1778kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006263%
# 27it [00:00, 93.43it/s] ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/0d62d429-5782-4f40-b682-9aa5bdd5cedf.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/0d62d429-5782-4f40-b682-9aa5bdd5cedf.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1811kB time=00:00:09.61 bitrate=1542.6kbits/s speed= 719x
# video:0kB audio:1811kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006146%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/25b1b7c0-f939-426a-bffa-ac64888a00b4.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/25b1b7c0-f939-426a-bffa-ac64888a00b4.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1204kB time=00:00:06.36 bitrate=1550.5kbits/s speed= 636x
# video:0kB audio:1204kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.009248%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/95c41fec-38ea-4144-a071-22baf4981bdb.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/95c41fec-38ea-4144-a071-22baf4981bdb.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1429kB time=00:00:07.56 bitrate=1548.2kbits/s speed= 496x
# video:0kB audio:1429kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007792%
# 37it [00:00, 75.92it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/11c1e2d8-52e2-4e32-8ab8-b858268e0ca9.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/11c1e2d8-52e2-4e32-8ab8-b858268e0ca9.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.71 bitrate=1545.7kbits/s speed= 534x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/1ca6d469-08a0-4d4d-878b-4b17c768ede2.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/1ca6d469-08a0-4d4d-878b-4b17c768ede2.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1845kB time=00:00:09.77 bitrate=1545.6kbits/s speed= 705x
# video:0kB audio:1845kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006034%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/05137f19-0400-4830-aab9-569b8b0b6f52.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/05137f19-0400-4830-aab9-569b8b0b6f52.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=     866kB time=00:00:04.57 bitrate=1552.3kbits/s speed= 410x
# video:0kB audio:866kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012852%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/2499bd0e-4221-449a-8184-ee15e1c80b35.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/2499bd0e-4221-449a-8184-ee15e1c80b35.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=     698kB time=00:00:03.66 bitrate=1560.8kbits/s speed= 672x
# video:0kB audio:698kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.015961%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/0b0b0aa7-b3fd-43f5-8292-9687f7df34de.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/0b0b0aa7-b3fd-43f5-8292-9687f7df34de.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1103kB time=00:00:05.81 bitrate=1552.1kbits/s speed= 514x
# video:0kB audio:1102kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.010098%
# 46it [00:00, 55.11it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/1e6da7fc-075d-40ca-b22d-99125c99b73a.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/1e6da7fc-075d-40ca-b22d-99125c99b73a.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.78 bitrate=1535.9kbits/s speed= 952x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/a08d28dc-9b8d-43ae-a864-9f25be0e1718.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/a08d28dc-9b8d-43ae-a864-9f25be0e1718.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.72 bitrate=1545.3kbits/s speed= 876x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# 56it [00:00, 62.98it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/1b0b6bde-cd4a-47b7-a365-cff01b91d19d.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/1b0b6bde-cd4a-47b7-a365-cff01b91d19d.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1744kB time=00:00:09.24 bitrate=1546.1kbits/s speed= 594x
# video:0kB audio:1744kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006384%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/618fc43a-4d9d-4dad-8b68-2714b584ccc4.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/618fc43a-4d9d-4dad-8b68-2714b584ccc4.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1856kB time=00:00:09.83 bitrate=1545.5kbits/s speed= 475x
# video:0kB audio:1856kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005997%
# 70it [00:00, 80.43it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/189bc1b8-e78d-48ce-a7da-2f1285b83106.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/189bc1b8-e78d-48ce-a7da-2f1285b83106.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1868kB time=00:00:09.89 bitrate=1546.2kbits/s speed= 921x
# video:0kB audio:1868kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005961%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/0a6bc12b-ea27-4167-a436-2a70f29e956e.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/0a6bc12b-ea27-4167-a436-2a70f29e956e.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1845kB time=00:00:09.77 bitrate=1545.8kbits/s speed= 974x
# video:0kB audio:1845kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006034%
# 80it [00:01, 84.58it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/15a2df04-2217-4809-89de-c07108a475c8.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/15a2df04-2217-4809-89de-c07108a475c8.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1856kB time=00:00:09.84 bitrate=1545.4kbits/s speed= 807x
# video:0kB audio:1856kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005997%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/2775e1cc-a85a-4c6a-8a4d-b4e225613d23.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/2775e1cc-a85a-4c6a-8a4d-b4e225613d23.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.71 bitrate=1545.7kbits/s speed= 532x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
# ...
# video:0kB audio:1114kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.009996%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/16f9b161-86c6-4af1-99cb-0ab327f10fed.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/16f9b161-86c6-4af1-99cb-0ab327f10fed.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1856kB time=00:00:09.84 bitrate=1545.4kbits/s speed= 417x
# video:0kB audio:1856kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005997%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/f028405b-2f4f-4379-ba3e-acc7a69f90be.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/f028405b-2f4f-4379-ba3e-acc7a69f90be.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1013kB time=00:00:05.33 bitrate=1553.6kbits/s speed= 667x
# video:0kB audio:1012kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.010995%
# 3740it [01:01, 61.56it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/29a160ac-2d0f-4bfc-be26-bc39695913e6.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/29a160ac-2d0f-4bfc-be26-bc39695913e6.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1440kB time=00:00:07.61 bitrate=1548.3kbits/s speed= 658x
# video:0kB audio:1440kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007731%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/011a31c2-9812-4521-aca4-ccb04be99a39.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/011a31c2-9812-4521-aca4-ccb04be99a39.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1508kB time=00:00:07.97 bitrate=1547.8kbits/s speed= 805x
# video:0kB audio:1508kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007385%
# 3750it [01:02, 68.33it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/25042fb0-ce92-4bd6-aa31-c234a1988f13.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/25042fb0-ce92-4bd6-aa31-c234a1988f13.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.71 bitrate=1545.7kbits/s speed= 649x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/294ffe19-a0a2-42f8-b262-ec1fc621a37c.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/294ffe19-a0a2-42f8-b262-ec1fc621a37c.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1845kB time=00:00:09.77 bitrate=1546.7kbits/s speed= 971x
# video:0kB audio:1845kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006034%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/224ee66d-7c74-474d-8123-360b75ed739c.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/224ee66d-7c74-474d-8123-360b75ed739c.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1823kB time=00:00:09.66 bitrate=1545.6kbits/s speed= 598x
# video:0kB audio:1822kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006109%
# 3760it [01:02, 60.47it/s]

# %% [markdown]
# ## Normalizing Cougvid Wav Files

# %%
if os.path.exists('dataset/Coughvid-Data/wav_normalized')==False:
    os.mkdir('dataset/Coughvid-Data/wav_normalized')

# %%
for i in os.listdir('dataset/Coughvid-Data/wav'):
    path = os.path.join('dataset/Coughvid-Data/wav',i)
    try:
        y, sr = lb.load(path, sr = None)
        y_norm = lb.util.normalize(y)
        y_re = lb.resample(y_norm, sr, 16000)
        loc = os.path.join('dataset/Coughvid-Data/wav_normalized',i)
        write(loc, 16000, y_re)
    except:
        print('None')

# %% [markdown]
# ## Creating Coughvid Normalized Data CSV

# %%
df_list = []
for index,row in coughvid.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    dataset = row['DataSet']
    if dataset == 'coughvid':
        paths = row['DIR']
        fn = paths.split('/')[-1].split('.')[0]
        loc = os.path.join('dataset/Coughvid-Data/wav_normalized',fn+'.wav')
        if os.path.exists(loc)==True:
            temp['filename'] = [fn+'.wav']
            temp['label'] = [row['STATUS']]
    df_list.append(temp)
VidData = pd.concat(df_list)
VidData = VidData.sample(frac=1).reset_index(drop=True)
VidData.to_csv('csv_files/normalized_data/Coughvid_dataset.csv', index=False)
VidData.head()
# Out:
#                                    filename     label
# 0  034aa6d3-6673-47a1-a319-325aa9be44a2.wav  negative
# 1  0527be95-d7f1-4156-8e37-1587355661ca.wav  negative
# 2  24dc7236-522f-4120-b76d-65538ab32b5b.wav  negative
# 3  17251011-d637-46b9-93b8-4237a98a5172.wav  negative
# 4  296c96b0-1b40-49b2-9c72-e1593a081897.wav  negative

# %% [markdown]
# ## Normalizing Coswara Wav Files

# %%
if os.path.exists('dataset/Coswara-Data/wav_normalized')==False:
    os.mkdir('dataset/Coswara-Data/wav_normalized')

# %%
coswara = pd.read_csv('csv_files/Merge_dataset.csv')
for index,row in coswara.iterrows():
    dataset = row['DataSet']
    if dataset == 'coswara':
        paths = row['DIR']
        fn = paths.split('/')[-2]
        try:
            y, sr = lb.load(paths, sr = None)
            y_norm = lb.util.normalize(y)
            y_re = lb.resample(y_norm, sr, 16000)
            loc = os.path.join('dataset/Coswara-Data/wav_normalized',fn+'.wav')
            write(loc, 16000, y_re)
        except:
            print('None')
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %% [markdown]
# ## Create Coswara Normalized Data CSV

# %%
df_list = []
for index,row in coughvid.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    dataset = row['DataSet']
    if dataset == 'coswara':
        paths = row['DIR']
        fn = paths.split('/')[-2]
        loc = os.path.join('dataset/Coswara-Data/wav_normalized',fn+'.wav')
        if os.path.exists(loc)==True:
            temp['filename'] = [fn+'.wav']
            temp['label'] = [row['STATUS']]
    df_list.append(temp)
CosData = pd.concat(df_list)
CosData = CosData.sample(frac=1).reset_index(drop=True)
CosData.to_csv('csv_files/normalized_data/Coswara_dataset.csv', index=False)
CosData.head()
# Out:
#                            filename     label
# 0  abpYyjmAQAMGlnyqXPGIL9lbnQo2.wav  negative
# 1  WedAZ6DrnjVQSxRJY8qRajogvtD2.wav  negative
# 2  PWXapCML3JSGefaCRAxKjCNp0Ps2.wav  negative
# 3  DRBAZX64nuVtqBQf13gH7r36Mh52.wav  negative
# 4  VJfAi0zEQHh3U8JAAdM6qwqQxmr1.wav  negative

# %% [markdown]
# ## Normalizing Compare Wav Files

# %%
if os.path.exists('dataset/Compare-Data/dist/wav_normalized')==False:
    os.mkdir('dataset/Compare-Data/dist/wav_normalized')

# %%
compare= pd.read_csv('csv_files/Merge_dataset.csv')
for index,row in compare.iterrows():
    dataset = row['DataSet']
    if dataset == 'compare':
        paths = row['DIR']
        fn = paths.split('/')[-1].split('.')[0]
        try:
            y, sr = lb.load(paths, sr = None)
            y_norm = lb.util.normalize(y)
            y_re = lb.resample(y_norm, sr, 16000)
            loc = os.path.join('dataset/Compare-Data/dist/wav_normalized',fn+'.wav')
            write(loc, 16000, y_re)
        except:
            print('None')

# %% [markdown]
# ## Create Compare Normalized Data CSV

# %%
df_list = []
for index,row in compare.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    dataset = row['DataSet']
    if dataset == 'compare':
        paths = row['DIR']
        fn = paths.split('/')[-1].split('.')[0]
        loc = os.path.join('dataset/Compare-Data/dist/wav_normalized',fn+'.wav')
        if os.path.exists(loc)==True:
            temp['filename'] = [fn+'.wav']
            temp['label'] = [row['STATUS']]
    df_list.append(temp)
CompData = pd.concat(df_list)
CompData = CompData.sample(frac=1).reset_index(drop=True)
CompData.to_csv('csv_files/normalized_data/Compare_dataset.csv', index=False)
CompData.head()
# Out:
#         filename     label
# 0  train_265.wav  negative
# 1   test_047.wav  positive
# 2  train_170.wav  negative
# 3  train_183.wav  negative
# 4  train_237.wav  negative

# %% [markdown]
# ## Merge Normalized Data

# %%
if os.path.exists('dataset/Merge-Data')==False:
    os.mkdir('dataset/Merge-Data')

# %%
for i in os.listdir('dataset/Coughvid-Data/wav_normalized'):
    source = os.path.join('dataset/Coughvid-Data/wav_normalized',i)
    target = os.path.join('dataset/Merge-Data',i)
    shutil.copyfile(source,target)

# %%
for i in os.listdir('dataset/Coswara-Data/wav_normalized'):
    source = os.path.join('dataset/Coswara-Data/wav_normalized',i)
    target = os.path.join('dataset/Merge-Data',i)
    shutil.copyfile(source,target)

# %%
for i in os.listdir('dataset/Compare-Data/dist/wav_normalized'):
    source = os.path.join('dataset/Compare-Data/dist/wav_normalized',i)
    target = os.path.join('dataset/Merge-Data',i)
    shutil.copyfile(source,target)

# %% [markdown]
# ## Create Merge Normalized Data CSV

# %%
coughvid = pd.read_csv('csv_files/normalized_data/Coughvid_dataset.csv')
coswara = pd.read_csv('csv_files/normalized_data/Coswara_dataset.csv')
compare = pd.read_csv('csv_files/normalized_data/Compare_dataset.csv')

MergeData = pd.concat([coughvid, coswara, compare])
MergeData = MergeData.sample(frac=1).reset_index(drop=True)
MergeData.to_csv('csv_files/normalized_data/Merge_dataset.csv', index=False)
MergeData.head()
# Out:
#                                    filename     label
# 0  09bffe1a-63f0-4f2e-942b-f7a152b344fc.wav  negative
# 1                             devel_080.wav  negative
# 2  277e5c0b-7676-4d62-b9da-6143e7ec10e3.wav  negative
# 3          90jN60jxwIMkR1qknR8Ziahvbe53.wav  negative
# 4          abpYyjmAQAMGlnyqXPGIL9lbnQo2.wav  negative

# %% [markdown]
# ## Create CSV for Experiment

# %%
if os.path.exists('csv_files/experiment_data')==False:
    os.mkdir('csv_files/experiment_data')

# %%
df_list = []
for index,row in MergeData.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    fn = row['filename']
    name = fn.split('.')[0].split('_')[0]
    if name == 'devel':
        temp['filename'] = [fn]
        temp['label'] = [row['label']]
    df_list.append(temp)
DevData = pd.concat(df_list)
DevData = DevData.sample(frac=1).reset_index(drop=True)
DevData.to_csv('csv_files/experiment_data/devel.csv', index=False)
DevData.head()
# Out:
#         filename     label
# 0  devel_176.wav  negative
# 1  devel_149.wav  negative
# 2  devel_196.wav  negative
# 3  devel_116.wav  negative
# 4  devel_123.wav  positive

# %%
df_list = []
for index,row in MergeData.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    fn = row['filename']
    name = fn.split('.')[0].split('_')[0]
    if name == 'test':
        temp['filename'] = [fn]
        temp['label'] = [row['label']]
    df_list.append(temp)
TestData = pd.concat(df_list)
TestData = TestData.sample(frac=1).reset_index(drop=True)
TestData.to_csv('csv_files/experiment_data/test.csv', index=False)
TestData.head()
# Out:
#        filename     label
# 0  test_094.wav  negative
# 1  test_179.wav  negative
# 2  test_113.wav  negative
# 3  test_105.wav  negative
# 4  test_114.wav  negative

# %%
df_list = []
for index,row in MergeData.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    fn = row['filename']
    name = fn.split('.')[0].split('_')[0]
    if name != 'test' and name != 'devel':
        temp['filename'] = [fn]
        temp['label'] = [row['label']]
    df_list.append(temp)
TrainData = pd.concat(df_list)
TrainData = TrainData.sample(frac=1).reset_index(drop=True)
TrainData.to_csv('csv_files/experiment_data/train.csv', index=False)
TrainData.head()
# Out:
#                            filename     label
# 0  YvhPqG9MqhbjHErOmOctaNdVdJZ2.wav  negative
# 1  t0wrpS8L5WamJS9NhyjeHAqhaVv1.wav  negative
# 2  QlMu7Fl8iIgOZM3QHEOzOJY6npH3.wav  negative
# 3  eSJm8nx2ygT4ZzQRzgYKpJiis1B2.wav  negative
# 4  NakKwA95snbM0W6Lk1nV0ptOmOA2.wav  negative
