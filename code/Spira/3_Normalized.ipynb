# %%
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import librosa as lb
from scipy.io.wavfile import write 
import matplotlib.pyplot as plt
import shutil

# %%
if os.path.exists('csv_files/normalized_data/')==False:
    os.mkdir('csv_files/normalized_data/')

# %% [markdown]
# ## Converting webm files to wav files

# %%
if os.path.exists('dataset/Coughvid-Data/wav')==False:
    os.mkdir('dataset/Coughvid-Data/wav')

# %%
coughvid = pd.read_csv('csv_files/Merge_dataset.csv')

# %%
for index,row in tqdm(coughvid.iterrows()):
    dataset = row['DataSet']
    if dataset == 'coughvid':
        paths = row['DIR']
        fn = paths.split('/')[-1].split('.')[0]
        loc = os.path.join('dataset/Coughvid-Data/wav',fn+'.wav')
        if (paths.endswith(".webm")):
            command = f"ffmpeg -i  {paths} -c:a pcm_f32le {loc}"
            os.system(command)
# Out:
# 0it [00:00, ?it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/774bafb8-5d1c-42c5-a0a8-91ba0a85a04b.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/774bafb8-5d1c-42c5-a0a8-91ba0a85a04b.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1800kB time=00:00:09.54 bitrate=1545.8kbits/s speed= 564x
# video:0kB audio:1800kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006185%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/58970bd3-2993-4762-8b21-0c5a2937c16b.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/58970bd3-2993-4762-8b21-0c5a2937c16b.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=     686kB time=00:00:03.59 bitrate=1562.1kbits/s speed= 634x
# video:0kB audio:686kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.016223%
# 8it [00:00, 77.87it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/b9e06a23-d76b-4164-b39a-64cd753a3c56.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/b9e06a23-d76b-4164-b39a-64cd753a3c56.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1845kB time=00:00:09.78 bitrate=1545.4kbits/s speed= 761x
# video:0kB audio:1845kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006034%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/f89ce6e7-5b0d-491f-8a69-c1c8c98166be.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/f89ce6e7-5b0d-491f-8a69-c1c8c98166be.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=     923kB time=00:00:04.85 bitrate=1555.3kbits/s speed= 677x
# video:0kB audio:922kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.012068%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/8f5531fb-5c2a-450b-b14c-4321085887d8.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/8f5531fb-5c2a-450b-b14c-4321085887d8.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.71 bitrate=1545.7kbits/s speed= 786x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# 17it [00:00, 73.26it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/ff8363d2-016d-4738-9499-4c62480886fb.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/ff8363d2-016d-4738-9499-4c62480886fb.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1845kB time=00:00:09.90 bitrate=1526.8kbits/s speed= 588x
# video:0kB audio:1845kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006034%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/068f9715-623a-45be-a17a-055a9028b4c6.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/068f9715-623a-45be-a17a-055a9028b4c6.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1823kB time=00:00:09.65 bitrate=1545.7kbits/s speed= 995x
# video:0kB audio:1822kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006109%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/d4e4b900-939e-48e9-ad9f-bf9eee425303.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/d4e4b900-939e-48e9-ad9f-bf9eee425303.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=     596kB time=00:00:03.12 bitrate=1565.6kbits/s speed= 458x
# video:0kB audio:596kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.018671%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/47ceafde-45d9-4bb6-881a-5ef866fa908d.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/47ceafde-45d9-4bb6-881a-5ef866fa908d.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.71 bitrate=1545.8kbits/s speed= 671x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# 25it [00:00, 51.21it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/8e03e0f4-c66b-41d2-b4bd-78e2d808f6cf.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/8e03e0f4-c66b-41d2-b4bd-78e2d808f6cf.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1845kB time=00:00:09.77 bitrate=1545.6kbits/s speed= 684x
# video:0kB audio:1845kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006034%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/0177b817-0ba3-498a-bc05-48bc66cc91b8.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/0177b817-0ba3-498a-bc05-48bc66cc91b8.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1856kB time=00:00:09.84 bitrate=1545.4kbits/s speed= 951x
# video:0kB audio:1856kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005997%
# 31it [00:00, 52.46it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# dataset/Coughvid-Data/public_dataset/c64d5b8f-42aa-4839-8eac-b6379f253d71.webm: No such file or directory
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/2efb0a76-18e3-40a5-b660-af8c19c9df10.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/2efb0a76-18e3-40a5-b660-af8c19c9df10.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1811kB time=00:00:09.59 bitrate=1546.4kbits/s speed=1.08e+03x
# video:0kB audio:1811kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006146%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/7f6db48d-de3f-4a30-bd9a-5216b0b3261b.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/7f6db48d-de3f-4a30-bd9a-5216b0b3261b.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1856kB time=00:00:09.84 bitrate=1544.6kbits/s speed= 625x
# video:0kB audio:1856kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005997%
# 41it [00:00, 59.02it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/a0bd7465-ae76-40cd-903b-3591ed9595db.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/a0bd7465-ae76-40cd-903b-3591ed9595db.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1856kB time=00:00:09.84 bitrate=1545.4kbits/s speed= 422x
# video:0kB audio:1856kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005997%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/43d84d62-8837-479b-bcb6-30effd9ecbc3.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/43d84d62-8837-479b-bcb6-30effd9ecbc3.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1868kB time=00:00:09.89 bitrate=1545.9kbits/s speed= 424x
# video:0kB audio:1868kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005961%
# 48it [00:00, 60.00it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/6088ee03-f819-40a2-bf26-29058e301ddd.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/6088ee03-f819-40a2-bf26-29058e301ddd.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.72 bitrate=1545.3kbits/s speed= 747x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/3e4f0ebc-7100-48a8-b164-4d90b8dee8db.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/3e4f0ebc-7100-48a8-b164-4d90b8dee8db.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1193kB time=00:00:06.29 bitrate=1551.4kbits/s speed= 721x
# video:0kB audio:1192kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.009336%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/bac8326b-2652-443d-8b58-af96cdf5284d.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/bac8326b-2652-443d-8b58-af96cdf5284d.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1879kB time=00:00:09.95 bitrate=1545.4kbits/s speed= 562x
# video:0kB audio:1879kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005926%
# 55it [00:00, 55.08it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/154161ff-1243-49c0-a377-72992b6954e3.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/154161ff-1243-49c0-a377-72992b6954e3.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1744kB time=00:00:09.24 bitrate=1546.1kbits/s speed= 710x
# video:0kB audio:1744kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006384%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/e5e9bc03-88b3-432f-b8d1-ca8891b72912.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/e5e9bc03-88b3-432f-b8d1-ca8891b72912.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1800kB time=00:00:09.53 bitrate=1545.8kbits/s speed= 461x
# video:0kB audio:1800kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006185%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
# ...
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/992b0d6a-7893-47a0-b655-5bf9e476db52.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/992b0d6a-7893-47a0-b655-5bf9e476db52.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=     855kB time=00:00:04.49 bitrate=1556.9kbits/s speed= 665x
# video:0kB audio:855kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.013021%
# 2580it [00:50, 84.94it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/88eed7b2-404d-4a3e-b18d-4eae00669b78.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/88eed7b2-404d-4a3e-b18d-4eae00669b78.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1856kB time=00:00:09.84 bitrate=1545.2kbits/s speed= 556x
# video:0kB audio:1856kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005997%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/195f9381-cf35-45da-b0ae-cc4ed04e9283.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/195f9381-cf35-45da-b0ae-cc4ed04e9283.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1845kB time=00:00:09.78 bitrate=1544.1kbits/s speed= 719x
# video:0kB audio:1845kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006034%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/70dbb19c-8c7a-45d4-9d2a-cd2272cc7ccb.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/70dbb19c-8c7a-45d4-9d2a-cd2272cc7ccb.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1215kB time=00:00:06.62 bitrate=1503.5kbits/s speed= 877x
# video:0kB audio:1215kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.009163%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/94a33ac9-c166-4795-9665-f7dd4f0caace.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/94a33ac9-c166-4795-9665-f7dd4f0caace.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1159kB time=00:00:06.11 bitrate=1551.3kbits/s speed= 729x
# video:0kB audio:1159kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.009608%
# ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/3f9a82e6-93b5-4d80-b8ae-09d36929d437.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/3f9a82e6-93b5-4d80-b8ae-09d36929d437.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.72 bitrate=1545.4kbits/s speed= 703x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# 2590it [00:50, 66.58it/s]ffmpeg version n4.4 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11.1.0 (GCC)
#   configuration: --prefix=/usr --disable-debug --disable-static --disable-stripping --enable-amf --enable-avisynth --enable-cuda-llvm --enable-lto --enable-fontconfig --enable-gmp --enable-gnutls --enable-gpl --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libdav1d --enable-libdrm --enable-libfreetype --enable-libfribidi --enable-libgsm --enable-libiec61883 --enable-libjack --enable-libmfx --enable-libmodplug --enable-libmp3lame --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libopenjpeg --enable-libopus --enable-libpulse --enable-librav1e --enable-librsvg --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtheora --enable-libv4l2 --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxcb --enable-libxml2 --enable-libxvid --enable-libzimg --enable-nvdec --enable-nvenc --enable-shared --enable-version3
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, matroska,webm, from 'dataset/Coughvid-Data/public_dataset/df1f1e45-0cd3-48dc-a5fa-eb7b201ece9d.webm':
#   Metadata:
#     encoder         : Chrome
#   Duration: N/A, start: 0.000000, bitrate: N/A
#   Stream #0:0(eng): Audio: opus, 48000 Hz, mono, fltp (default)
# Stream mapping:
#   Stream #0:0 -> #0:0 (opus (native) -> pcm_f32le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'dataset/Coughvid-Data/wav/df1f1e45-0cd3-48dc-a5fa-eb7b201ece9d.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0(eng): Audio: pcm_f32le ([3][0][0][0] / 0x0003), 48000 Hz, mono, flt, 1536 kb/s (default)
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_f32le
# size=    1834kB time=00:00:09.72 bitrate=1545.5kbits/s speed= 665x
# video:0kB audio:1834kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006071%
# 2595it [00:50, 51.33it/s]

# %% [markdown]
# ## Normalizing Cougvid Wav Files

# %%
if os.path.exists('dataset/Coughvid-Data/wav_normalized')==False:
    os.mkdir('dataset/Coughvid-Data/wav_normalized')

# %%
for i in os.listdir('dataset/Coughvid-Data/wav'):
    path = os.path.join('dataset/Coughvid-Data/wav',i)
    try:
        y, sr = lb.load(path, sr = None)
        y_norm = lb.util.normalize(y)
        y_re = lb.resample(y_norm, sr, 16000)
        loc = os.path.join('dataset/Coughvid-Data/wav_normalized',i)
        write(loc, 16000, y_re)
    except:
        print('None')

# %% [markdown]
# ## Creating Coughvid Normalized Data CSV

# %%
df_list = []
for index,row in coughvid.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    dataset = row['DataSet']
    if dataset == 'coughvid':
        paths = row['DIR']
        fn = paths.split('/')[-1].split('.')[0]
        loc = os.path.join('dataset/Coughvid-Data/wav_normalized',fn+'.wav')
        if os.path.exists(loc)==True:
            temp['filename'] = [fn+'.wav']
            temp['label'] = [row['STATUS']]
    df_list.append(temp)
VidData = pd.concat(df_list)
VidData = VidData.sample(frac=1).reset_index(drop=True)
VidData.to_csv('csv_files/normalized_data/Coughvid_dataset.csv', index=False)
VidData.head()
# Out:
#                                    filename     label
# 0  2c70a831-dc41-4d4b-85e8-07c4499b54fe.wav  positive
# 1  bc4e7e90-4dd2-45f6-a2a4-2c5df914000d.wav  positive
# 2  936268f0-41a3-421d-bd18-8e69e597e84c.wav  positive
# 3  4fc9a8e3-909a-4e92-9621-d5e578817f21.wav  positive
# 4  03c1afa7-eee5-4c18-bd40-c4d91e6d320e.wav  positive

# %% [markdown]
# ## Normalizing Coswara Wav Files

# %%
if os.path.exists('dataset/Coswara-Data/wav_normalized')==False:
    os.mkdir('dataset/Coswara-Data/wav_normalized')

# %%
coswara = pd.read_csv('csv_files/Merge_dataset.csv')
for index,row in coswara.iterrows():
    dataset = row['DataSet']
    if dataset == 'coswara':
        paths = row['DIR']
        name = paths.split('/')[-1].split('.')[0]
        if name == 'cough-shallow':
            fn = paths.split('/')[-2]
            try:
                y, sr = lb.load(paths, sr = None)
                y_norm = lb.util.normalize(y)
                y_re = lb.resample(y_norm, sr, 16000)
                loc = os.path.join('dataset/Coswara-Data/wav_normalized',fn+'.wav')
                write(loc, 16000, y_re)
            except:
                print('None')
        if name == 'cough-heavy':
            fn = paths.split('/')[-2]
            try:
                y, sr = lb.load(paths, sr = None)
                y_norm = lb.util.normalize(y)
                y_re = lb.resample(y_norm, sr, 16000)
                loc = os.path.join('dataset/Coswara-Data/wav_normalized',fn+'_heavy.wav')
                write(loc, 16000, y_re)
            except:
                print('None')
# Out:
# None
# None

# %% [markdown]
# ## Create Coswara Normalized Data CSV

# %%
coughvid = pd.read_csv('csv_files/Merge_dataset.csv')

# %%
df_list = []
for index,row in coughvid.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    dataset = row['DataSet']
    if dataset == 'coswara':
        paths = row['DIR']
        name = paths.split('/')[-1].split('.')[0]
        if name == 'cough-shallow':
            fn = paths.split('/')[-2]
            loc = os.path.join('dataset/Coswara-Data/wav_normalized',fn+'.wav')
            if os.path.exists(loc)==True:
                temp['filename'] = [fn+'.wav']
                temp['label'] = [row['STATUS']]
        if name == 'cough-heavy':
            fn = paths.split('/')[-2]
            loc = os.path.join('dataset/Coswara-Data/wav_normalized',fn+'_heavy.wav')
            if os.path.exists(loc)==True:
                temp['filename'] = [fn+'_heavy.wav']
                temp['label'] = [row['STATUS']]
    df_list.append(temp)
CosData = pd.concat(df_list)
CosData = CosData.sample(frac=1).reset_index(drop=True)
CosData.to_csv('csv_files/normalized_data/Coswara_dataset.csv', index=False)
CosData.head()
# Out:
#                                  filename     label
# 0  ir3jqGSKT2ManVTAAzj6Ew7orBD2_heavy.wav  positive
# 1        ZzKpUtFGzsVEK7E1wsVGRftKdx93.wav  positive
# 2        TkOj2GRygbe2J9HxfMWk02A4e7v1.wav  positive
# 3  ottC8aetxhRQfKD00RCJc5LWS622_heavy.wav  positive
# 4        IFMid2LmeCTSQAFaL8wTSUg20No2.wav  positive

# %% [markdown]
# ## Normalizing Compare Wav Files

# %%
if os.path.exists('dataset/Compare-Data/dist/wav_normalized')==False:
    os.mkdir('dataset/Compare-Data/dist/wav_normalized')

# %%
compare= pd.read_csv('csv_files/Merge_dataset.csv')
for index,row in compare.iterrows():
    dataset = row['DataSet']
    if dataset == 'compare':
        paths = row['DIR']
        fn = paths.split('/')[-1].split('.')[0]
        try:
            y, sr = lb.load(paths, sr = None)
            y_norm = lb.util.normalize(y)
            y_re = lb.resample(y_norm, sr, 16000)
            loc = os.path.join('dataset/Compare-Data/dist/wav_normalized',fn+'.wav')
            write(loc, 16000, y_re)
        except:
            print('None')

# %% [markdown]
# ## Create Compare Normalized Data CSV

# %%
df_list = []
for index,row in compare.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    dataset = row['DataSet']
    if dataset == 'compare':
        paths = row['DIR']
        fn = paths.split('/')[-1].split('.')[0]
        loc = os.path.join('dataset/Compare-Data/dist/wav_normalized',fn+'.wav')
        if os.path.exists(loc)==True:
            temp['filename'] = [fn+'.wav']
            temp['label'] = [row['STATUS']]
    df_list.append(temp)
CompData = pd.concat(df_list)
CompData = CompData.sample(frac=1).reset_index(drop=True)
CompData.to_csv('csv_files/normalized_data/Compare_dataset.csv', index=False)
CompData.head()
# Out:
#         filename     label
# 0  train_265.wav  negative
# 1   test_047.wav  positive
# 2  train_170.wav  negative
# 3  train_183.wav  negative
# 4  train_237.wav  negative

# %% [markdown]
# ## Merge Normalized Data

# %%
if os.path.exists('dataset/Merge-Data')==False:
    os.mkdir('dataset/Merge-Data')

# %%
for i in os.listdir('dataset/Coughvid-Data/wav_normalized'):
    source = os.path.join('dataset/Coughvid-Data/wav_normalized',i)
    target = os.path.join('dataset/Merge-Data',i)
    shutil.copyfile(source,target)

# %%
for i in os.listdir('dataset/Coswara-Data/wav_normalized'):
    source = os.path.join('dataset/Coswara-Data/wav_normalized',i)
    target = os.path.join('dataset/Merge-Data',i)
    shutil.copyfile(source,target)

# %%
for i in os.listdir('dataset/Compare-Data/dist/wav_normalized'):
    source = os.path.join('dataset/Compare-Data/dist/wav_normalized',i)
    target = os.path.join('dataset/Merge-Data',i)
    shutil.copyfile(source,target)

# %% [markdown]
# ## Create Merge Normalized Data CSV

# %%
coughvid = pd.read_csv('csv_files/normalized_data/Coughvid_dataset.csv')
coswara = pd.read_csv('csv_files/normalized_data/Coswara_dataset.csv')
compare = pd.read_csv('csv_files/normalized_data/Compare_dataset.csv')

MergeData = pd.concat([coughvid, coswara, compare])
MergeData = MergeData.sample(frac=1).reset_index(drop=True)
MergeData.to_csv('csv_files/normalized_data/Merge_dataset.csv', index=False)
MergeData.head()
# Out:
#                                    filename     label
# 0  e67cd4b2-b2c1-4654-b5cb-bbff69a5cf86.wav  positive
# 1          YuahWhZmLgMcw3hpc83mcz06bMS2.wav  positive
# 2                             train_095.wav  negative
# 3  731cbe07-5754-46cf-bb5c-873a670cd5d7.wav  positive
# 4  6a04b4c4-3998-496e-b4a1-209d16e27adb.wav  positive

# %% [markdown]
# ## Create CSV for Experiment

# %%
if os.path.exists('csv_files/experiment_data')==False:
    os.mkdir('csv_files/experiment_data')

# %%
coughvid = pd.read_csv('csv_files/normalized_data/Coughvid_dataset.csv')
coswara = pd.read_csv('csv_files/normalized_data/Coswara_dataset.csv')
compare = pd.read_csv('csv_files/normalized_data/Compare_dataset.csv')
MergeData = pd.read_csv('csv_files/normalized_data/Merge_dataset.csv')

# %%
partisi = 0.2

# %%
df_list = []
for index, row in coughvid.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    fn = row['filename']
    temp['filename'] = [fn]
    temp['label'] = [row['label']]
    df_list.append(temp)
num = int(partisi*len(df_list))

VidDevData = pd.concat(df_list[0:num])
VidDevData.to_csv('csv_files/experiment_data/coughvid_devel.csv', index=False)

VidTrainData = pd.concat(df_list[num:])
VidTrainData.to_csv('csv_files/experiment_data/coughvid_train.csv', index=False)

# %%
VidDevData.head()
# Out:
#                                    filename     label
# 0  2c70a831-dc41-4d4b-85e8-07c4499b54fe.wav  positive
# 0  bc4e7e90-4dd2-45f6-a2a4-2c5df914000d.wav  positive
# 0  936268f0-41a3-421d-bd18-8e69e597e84c.wav  positive
# 0  4fc9a8e3-909a-4e92-9621-d5e578817f21.wav  positive
# 0  03c1afa7-eee5-4c18-bd40-c4d91e6d320e.wav  positive

# %%
VidTrainData.head()
# Out:
#                                    filename     label
# 0  e8f4b378-f21c-40a6-add1-2831323f544e.wav  positive
# 0  d4e4b900-939e-48e9-ad9f-bf9eee425303.wav  positive
# 0  f6dc7637-6214-4f47-9063-3cbfb8b3b519.wav  positive
# 0  d5b05c83-3dab-4fc9-8db7-9f46bcb06cac.wav  positive
# 0  a41a84b6-f192-4b79-bb08-e47285cf8a4e.wav  positive

# %%
df_list = []
for index, row in coswara.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    fn = row['filename']
    temp['filename'] = [fn]
    temp['label'] = [row['label']]
    df_list.append(temp)
num = int(partisi*len(df_list))

CosDevData = pd.concat(df_list[0:num])
CosDevData.to_csv('csv_files/experiment_data/coswara_devel.csv', index=False)

CosTrainData = pd.concat(df_list[num:])
CosTrainData.to_csv('csv_files/experiment_data/coswara_train.csv', index=False)

# %%
CosDevData.head()
# Out:
#                                  filename     label
# 0  ir3jqGSKT2ManVTAAzj6Ew7orBD2_heavy.wav  positive
# 0        ZzKpUtFGzsVEK7E1wsVGRftKdx93.wav  positive
# 0        TkOj2GRygbe2J9HxfMWk02A4e7v1.wav  positive
# 0  ottC8aetxhRQfKD00RCJc5LWS622_heavy.wav  positive
# 0        IFMid2LmeCTSQAFaL8wTSUg20No2.wav  positive

# %%
CosTrainData.head()
# Out:
#                                  filename     label
# 0        aHJPsm6esHeW5apkd8KAFdia9zj2.wav  positive
# 0        ptuwF1pj4ibIoVuZmt4nKb5naiZ2.wav  positive
# 0  EbWP0XeMpnbrTsljro0dOGKIell1_heavy.wav  positive
# 0  Ued1DKV2NkUnzWjJcPMxA6Q261r1_heavy.wav  positive
# 0        ZaeW7vuikQgf7984JVqXYOtUQMs2.wav  positive

# %%
df_list = []
for index,row in MergeData.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    fn = row['filename']
    name = fn.split('.')[0].split('_')[0]
    if name == 'devel':
        temp['filename'] = [fn]
        temp['label'] = [row['label']]
    df_list.append(temp)
ComDevData = pd.concat(df_list)
ComDevData.to_csv('csv_files/experiment_data/compare_devel.csv', index=False)
ComDevData.head()
# Out:
#         filename     label
# 0  devel_040.wav  negative
# 0  devel_204.wav  negative
# 0  devel_164.wav  negative
# 0  devel_020.wav  negative
# 0  devel_130.wav  negative

# %%
df_list = []
for index,row in MergeData.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    fn = row['filename']
    name = fn.split('.')[0].split('_')[0]
    if name == 'test':
        temp['filename'] = [fn]
        temp['label'] = [row['label']]
    df_list.append(temp)
TestData = pd.concat(df_list)
TestData = TestData.sample(frac=1).reset_index(drop=True)
TestData.to_csv('csv_files/experiment_data/test.csv', index=False)
TestData.head()
# Out:
#        filename     label
# 0  test_011.wav  positive
# 1  test_108.wav  positive
# 2  test_087.wav  negative
# 3  test_101.wav  negative
# 4  test_052.wav  positive

# %%
df_list = []
for index,row in compare.iterrows():
    temp = pd.DataFrame(columns=['filename','label'])
    fn = row['filename']
    name = fn.split('.')[0].split('_')[0]
    if name == 'train':
        temp['filename'] = [fn]
        temp['label'] = [row['label']]
    df_list.append(temp)
ComTrainData = pd.concat(df_list)
ComTrainData.to_csv('csv_files/experiment_data/compare_train.csv', index=False)
ComTrainData.head()
# Out:
#         filename     label
# 0  train_265.wav  negative
# 0  train_170.wav  negative
# 0  train_183.wav  negative
# 0  train_237.wav  negative
# 0  train_196.wav  positive

# %%
DevData = pd.concat([CosDevData, VidDevData, ComDevData])
DevData.to_csv('csv_files/experiment_data/devel.csv', index=False)
DevData.head()
# Out:
#                                  filename     label
# 0  ir3jqGSKT2ManVTAAzj6Ew7orBD2_heavy.wav  positive
# 0        ZzKpUtFGzsVEK7E1wsVGRftKdx93.wav  positive
# 0        TkOj2GRygbe2J9HxfMWk02A4e7v1.wav  positive
# 0  ottC8aetxhRQfKD00RCJc5LWS622_heavy.wav  positive
# 0        IFMid2LmeCTSQAFaL8wTSUg20No2.wav  positive

# %%
TrainData = pd.concat([CosTrainData, VidTrainData, ComTrainData])
TrainData.to_csv('csv_files/experiment_data/train.csv', index=False)
TrainData.head()
# Out:
#                                  filename     label
# 0        aHJPsm6esHeW5apkd8KAFdia9zj2.wav  positive
# 0        ptuwF1pj4ibIoVuZmt4nKb5naiZ2.wav  positive
# 0  EbWP0XeMpnbrTsljro0dOGKIell1_heavy.wav  positive
# 0  Ued1DKV2NkUnzWjJcPMxA6Q261r1_heavy.wav  positive
# 0        ZaeW7vuikQgf7984JVqXYOtUQMs2.wav  positive
